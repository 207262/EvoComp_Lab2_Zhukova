# %% [markdown]
# # Original algorithm
# ## Graph
# ![111.png](attachment:111.png)
#
# ## Result
# ![Screenshot%202020-12-29%20at%203.10.01%20AM.png](attachment:Screenshot%202020-12-29%20at%203.10.01%20AM.png)

# %% [markdown]
# # Modified algorithm
# ## Graph
# ![2.png](attachment:2.png)
#
# ## Result
# ![222.png](attachment:222.png)
#
# ##### Mean value = 200
